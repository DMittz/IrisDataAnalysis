# %% [markdown]
# <a href="https://colab.research.google.com/github/DMittz/SupervisedLearning/blob/main/DiabetesDatasetAnalysis_1.2_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
from sklearn.datasets import load_diabetes
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix

# %%
df = pd.read_csv("diabetes[1].csv")

# %%
print(df)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %% [markdown]
# Seaborn:

# %%
sns.pairplot(data=df, hue = 'Outcome')

# %%
sns.heatmap(df.corr(), annot = True)

# %% [markdown]
# Data Imputation:

# %%
average = round(df['Glucose'].mean())
average_bp = round(df['BloodPressure'].mean())

# %%
df.loc[df['Glucose'] == 0, 'Glucose'] = average
df.loc[df['BloodPressure'] == 0, 'BloodPressure'] = average_bp

# %%
check = 0
for item in df['Glucose']:
  if item == 0:
    check += 1
print(check)
# Out:
# 0

# %%
df.drop(['SkinThickness'], axis = 1)

# %% [markdown]
# SKLearn:

# %%
features = df.drop(['Outcome'], axis = 1)

# %%
labels = df['Outcome']

# %%
x_train, x_test, y_train, y_test = train_test_split(features, labels, test_size = 0.50, random_state = 42)

# %%
clf = DecisionTreeClassifier()
clf.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
pred = clf.predict(x_test)

# %%
print(confusion_matrix(y_test, pred))
# Out:
# [[187  67]
#  [ 48  82]]
